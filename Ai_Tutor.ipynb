# %%
# !pip install openAI

# %%
import openai

# %%
openai.api_key="Enter_your_API_Key_here"

# %%
messages=[

         {"role":"system","content":"you are a good assistant that help human to tell whether a review is good/bad/okay only ."},
         {"role":"user","content":"the paneer dish neither too good nor too bad it is a one time experience"}
]
messages
# Out:
# [{'role': 'system',
#   'content': 'you are a good assistant that help human to tell whether a review is good/bad/okay only .'},
#  {'role': 'user',
#   'content': 'the paneer dish neither too good nor too bad it is a one time experience'}]

# %%
messages=[

         {"role":"system","content":"you are a good assistant that help human to tell whether a review is accha/bura."},
         {"role":"user","content":"the ambience of the restraunt was good but the food was pathetic which spoiled my whole experience the food"}
]
messages
# Out:
# [{'role': 'system',
#   'content': 'you are a good assistant that help human to tell whether a review is accha/bura.'},
#  {'role': 'user',
#   'content': 'the ambience of the restraunt was good but the food was pathetic which spoiled my whole experience the food'}]

# %%
messages=[

         {"role":"system","content":"you are a good assistant that help human to tell whether a review is good/bad/average only"},
         {"role":"user","content":"the food and the place were amazing will definetly come here next time"}
]
messages
# Out:
# [{'role': 'system',
#   'content': 'you are a good assistant that help human to tell whether a review is good/bad/average only'},
#  {'role': 'user',
#   'content': 'the food and the place were amazing will definetly come here next time'}]

# %%
messages=[

         {"role":"system","content":"you are a good assistant that answer only the questions related to data science if any other questions asked then reply question does not related to my field"},
         {"role":"user","content":"what is the capital of india "}
]
messages
# Out:
# [{'role': 'system',
#   'content': 'you are a good assistant that answer only the questions related to data science if any other questions asked then reply question does not related to my field'},
#  {'role': 'user', 'content': 'what is the capital of india '}]

# %%
messages=[

         {"role":"system","content":"you are a good assistant that answer only the questions related to data science if any other questions asked then reply question does not related to my field"},
         {"role":"user","content":"what is machine learning "}
]
messages
# Out:
# [{'role': 'system',
#   'content': 'you are a good assistant that answer only the questions related to data science if any other questions asked then reply question does not related to my field'},
#  {'role': 'user', 'content': 'what is machine learning '}]

# %%
messages=[

         {"role":"system","content":"you are a good assistant and you are a time table maker for 3rd year btech student where a student comes confused about how to manage different subject along with workshop and placement drive . the ai assistant should give them a structured timetable which they can follow consistently without getting distracted.
"},
         {"role":"user","content":"the food and the place were amazing will definetly come here next time"}
]
messages

# %%
chat_response=openai.chat.completions.create(
    model="gpt-3.5-turbo-16k",
    messages=messages
)
chat_response
# Out:
# ChatCompletion(id='chatcmpl-DTtu9BCdJOO0zFu7x6EzBkrVLIcO9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='This is a good review.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1776018781, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=6, prompt_tokens=46, total_tokens=52, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
chat_response.choices[0].message.content
# Out:
# 'This is a good review.'
