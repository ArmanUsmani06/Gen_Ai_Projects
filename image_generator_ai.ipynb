# %%
# !pip install config
# Out:
# Collecting config
#   Downloading config-0.5.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading config-0.5.1-py2.py3-none-any.whl (20 kB)
# Installing collected packages: config
# Successfully installed config-0.5.1

# %%
import openai
import config

# %%
openai.api_key="Enter_your_API_Key_here"

# %%
from openai import OpenAI
client=OpenAI(api_key=openai.api_key)

# %%
response = client.images.generate(
    model="dall-e-2",
    prompt="an apple floating in water",
    n=1,
    size="1024x1024",
)
image_url=response.data[0].url

print(f"your image is ready at : {image_url}")
# Out:
# your image is ready at : https://oaidalleapiprodscus.blob.core.windows.net/private/org-O4O0A3fYZ6rhpXtt8U3AKtam/user-wcMXDUSpVuwG5Fxzs9DOpXL4/img-er3Tqnk28bq4b0KA34PTG64q.png?st=2026-04-06T08%3A09%3A59Z&se=2026-04-06T10%3A09%3A59Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=13da7400-b3f7-4f8c-9cba-908fecbd114c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-04-05T22%3A04%3A03Z&ske=2026-04-06T22%3A04%3A03Z&sks=b&skv=2026-02-06&sig=FuX6f/nMLAmB0dA8UYQETmM3T9L6RgYyoF2pDqjktQc%3D
